# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame, Panel
pd.set_option('display.max_rows',15) # this limit maximum numbers of rows
# Out:
# C:\Users\richa\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# "switch on" inline graphic for the notebook
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ao = np.loadtxt("C:/Users/richa/DropBox_iovi/Dropbox/Tutorial/ML_Mastery/Data/monthly.ao.index.b50.current.ascii")

# %%
ao[:2]
# Out:
# array([[ 1.9500e+03,  1.0000e+00, -6.0310e-02],
#        [ 1.9500e+03,  2.0000e+00,  6.2681e-01]])

# %%
ao.shape
# Out:
# (840, 3)

# %%
dates = pd.date_range('1950-01', periods=ao.shape[0], freq='M')

# %%
print(dates)
# Out:
# DatetimeIndex(['1950-01-31', '1950-02-28', '1950-03-31', '1950-04-30',
#                '1950-05-31', '1950-06-30', '1950-07-31', '1950-08-31',
#                '1950-09-30', '1950-10-31',
#                ...
#                '2019-03-31', '2019-04-30', '2019-05-31', '2019-06-30',
#                '2019-07-31', '2019-08-31', '2019-09-30', '2019-10-31',
#                '2019-11-30', '2019-12-31'],
#               dtype='datetime64[ns]', length=840, freq='M')

# %%
dates.shape
# Out:
# (840,)

# %%
AO = Series(ao[:,2], index=dates)

# %%
print(AO)
# Out:
# 1950-01-31   -0.060310
# 1950-02-28    0.626810
# 1950-03-31   -0.008127
# 1950-04-30    0.555100
# 1950-05-31    0.071577
#                 ...
# 2019-08-31   -0.721770
# 2019-09-30    0.306200
# 2019-10-31   -0.082195
# 2019-11-30   -1.193400
# 2019-12-31    0.412070
# Freq: M, Length: 840, dtype: float64

# %%
AO.plot()

# %%
AO['1980':'1990'].plot()

# %%
AO['1990-01':'1992-03'].plot()

# %%
AO['1976']
# Out:
# 1976-01-31    0.034333
# 1976-02-29    1.656300
# 1976-03-31    0.587090
# 1976-04-30    0.439680
# 1976-05-31    0.059626
# 1976-06-30    0.328000
# 1976-07-31   -0.325290
# 1976-08-31    0.558590
# 1976-09-30   -0.742520
# 1976-10-31   -0.804120
# 1976-11-30   -0.087349
# 1976-12-31   -2.074300
# Freq: M, dtype: float64

# %%
nao = np.loadtxt("C:/Users/richa/DropBox_iovi/Dropbox/Tutorial/ML_Mastery/Data/norm.nao.monthly.b5001.current.ascii")

# %%
dates_nao = pd.date_range('1950-01', periods=nao.shape[0], freq="M")
NAO = Series(nao[:,2], index=dates_nao)

# %%
NAO.index
# Out:
# DatetimeIndex(['1950-01-31', '1950-02-28', '1950-03-31', '1950-04-30',
#                '1950-05-31', '1950-06-30', '1950-07-31', '1950-08-31',
#                '1950-09-30', '1950-10-31',
#                ...
#                '2019-03-31', '2019-04-30', '2019-05-31', '2019-06-30',
#                '2019-07-31', '2019-08-31', '2019-09-30', '2019-10-31',
#                '2019-11-30', '2019-12-31'],
#               dtype='datetime64[ns]', length=840, freq='M')

# %%
aonao = DataFrame({"AO":AO, "NAO":NAO})

# %%
print(aonao)
# Out:
#                   AO      NAO
# 1950-01-31 -0.060310  0.92000
# 1950-02-28  0.626810  0.40000
# 1950-03-31 -0.008127 -0.36000
# 1950-04-30  0.555100  0.73000
# 1950-05-31  0.071577 -0.59000
# ...              ...      ...
# 2019-08-31 -0.721770 -1.16840
# 2019-09-30  0.306200 -0.16408
# 2019-10-31 -0.082195 -1.41340
# 2019-11-30 -1.193400  0.27847
# 2019-12-31  0.412070  1.20160
#
# [840 rows x 2 columns]

# %%
aonao.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000238C65BEC88>,
# ...
#       dtype=object)

# %%
print(aonao.head())
# Out:
#                   AO   NAO
# 1950-01-31 -0.060310  0.92
# 1950-02-28  0.626810  0.40
# 1950-03-31 -0.008127 -0.36
# 1950-04-30  0.555100  0.73
# 1950-05-31  0.071577 -0.59

# %%
print(aonao["NAO"])
# Out:
# 1950-01-31    0.92000
# 1950-02-28    0.40000
# 1950-03-31   -0.36000
# 1950-04-30    0.73000
# 1950-05-31   -0.59000
#                ...
# 2019-08-31   -1.16840
# 2019-09-30   -0.16408
# 2019-10-31   -1.41340
# 2019-11-30    0.27847
# 2019-12-31    1.20160
# Freq: M, Name: NAO, Length: 840, dtype: float64

# %%
aonao['Diff'] = aonao['AO'] - aonao['NAO']

# %%
print(aonao.head())
# Out:
#                   AO   NAO      Diff
# 1950-01-31 -0.060310  0.92 -0.980310
# 1950-02-28  0.626810  0.40  0.226810
# 1950-03-31 -0.008127 -0.36  0.351872
# 1950-04-30  0.555100  0.73 -0.174900
# 1950-05-31  0.071577 -0.59  0.661577

# %%
aonao['1981-01':'1981-03']['Diff']
# Out:
# 1981-01-31   -0.48634
# 1981-02-28   -1.25158
# 1981-03-31   -0.45470
# Freq: M, Name: Diff, dtype: float64

# %%
aonao.mean()
# Out:
# AO     -0.107179
# NAO    -0.003772
# Diff   -0.103406
# dtype: float64

# %%
aonao.max()
# Out:
# AO      3.4953
# NAO     3.0400
# Diff    2.6693
# dtype: float64

# %%
aonao.min()
# Out:
# AO     -4.2657
# NAO    -3.1800
# Diff   -2.7271
# dtype: float64

# %%
aonao.mean(1)
# Out:
# 1950-01-31   -0.040207
# 1950-02-28    0.417873
# 1950-03-31   -0.005418
# 1950-04-30    0.370067
# 1950-05-31    0.047718
#                 ...
# 2019-08-31   -0.481180
# 2019-09-30    0.204133
# 2019-10-31   -0.054797
# 2019-11-30   -0.795600
# 2019-12-31    0.274713
# Freq: M, Length: 840, dtype: float64

# %%
aonao = DataFrame({"AO":AO.to_period('M'), "NAO":NAO.to_period('M')})

# %%
aonao.head()
# Out:
#                AO   NAO
# 1950-01 -0.060310  0.92
# 1950-02  0.626810  0.40
# 1950-03 -0.008127 -0.36
# 1950-04  0.555100  0.73
# 1950-05  0.071577 -0.59

# %%
type(NAO.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
q_mean = aonao.open.resample('Q-NOV')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-c488173651ab> in <module>
# ----> 1 q_mean = aonao.open.resample('Q-NOV')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'open'

# %%
q_mean[q_mean.index.quarter==1].plot(figsize=(8,5))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-f8df7acfd3ab> in <module>
# ----> 1 q_mean[q_mean.index.quarter==1].plot(figsize=(8,5))
#
# ~\Anaconda3\lib\site-packages\pandas\core\resample.py in __getattr__(self, attr)
#     108             return self[attr]
#     109
# --> 110         return object.__getattribute__(self, attr)
#     111
#     112     def __iter__(self):
#
# AttributeError: 'PeriodIndexResampler' object has no attribute 'index'

# %%
m3_mean = aonao[2:].resample('3M', closed='left')

# %%
m3_mean
